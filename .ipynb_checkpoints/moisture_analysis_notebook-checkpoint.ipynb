# %% [markdown]
# # Moisture index analysis and color detection using Machine Learning
#
# #### source: https://towardsdatascience.com/color-identification-in-images-machine-learning-application-b26e770c4c71

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import cv2
from collections import Counter
from skimage.color import rgb2lab, deltaE_cie76
import os

# %matplotlib inline

# %%
# Example of data source
datasource = 'data/mositure_images/2021-03-10-00_00_2021-03-10-23_59_Sentinel-2_L2A_Moisture_index.jpg'

image = cv2.imread(datasource)

print("The type of this input is {}".format(type(image)))
print("Shape: {}".format(image.shape))
plt.imshow(image)
# Out:
# The type of this input is <class 'numpy.ndarray'>
# Shape: (957, 1920, 3)

# %%
# Original colors

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
# Black and white colors
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image, cmap='gray')

# %% [markdown]
# ## Machine Learning
#
# #### KMeans is used to first fit and then predict on the image to get the color results. The cluster of colors is identified and plotted as a pie chart. Here the color abundance in the printed output of `get_colors` represents the areas with most moisture.

# %%
def RGB2HEX(color):
    return "#{:02x}{:02x}{:02x}".format(int(color[0]), int(color[1]), int(color[2]))


def get_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    return image





def get_colors(image, number_of_colors, show_chart):
    
    modified_image = cv2.resize(image, (600, 400), interpolation = cv2.INTER_AREA)
    modified_image = modified_image.reshape(modified_image.shape[0]*modified_image.shape[1], 3)
    
    clf = KMeans(n_clusters = number_of_colors)
    labels = clf.fit_predict(modified_image)
    
    counts = Counter(labels)
    # sort to ensure correct color percentage
    counts = dict(sorted(counts.items()))
    
    count_total = 0 
    for element in counts.values():
        count_total += element
    print(count_total)
    rgb_ratios_to_total = []
    for i in counts.values():
        ratio = float(i)/count_total
        rgb_ratios_to_total.append(ratio)
        #print("Ratio of color to total: ",ratio)
    
    center_colors = clf.cluster_centers_
    # We get ordered colors by iterating through the keys
    ordered_colors = [center_colors[i] for i in counts.keys()]
    hex_colors = [RGB2HEX(ordered_colors[i]) for i in counts.keys()]
    rgb_colors = [ordered_colors[i] for i in counts.keys()]
    if (show_chart):
      for i in range(len(counts.keys())):
        print("Color: ", hex_colors[i], " color abundance: ", rgb_ratios_to_total[i])
        
    if (show_chart):
        plt.figure(figsize = (8, 6))
        plt.pie(counts.values(), labels = hex_colors, colors = hex_colors)
        
    return rgb_colors

# %%
get_colors(get_image(datasource), 8, True)
# Out:
# 240000
# Color:  #000098  color abundance:  0.3345375
# Color:  #f2cf0d  color abundance:  0.0833
# Color:  #57e7ad  color abundance:  0.0528
# Color:  #0769f5  color abundance:  0.0803375
# Color:  #0207e2  color abundance:  0.2639916666666667
# Color:  #a8f15d  color abundance:  0.0456
# Color:  #324962  color abundance:  0.043
# Color:  #10caef  color abundance:  0.09643333333333333
# [array([  0.74244292,   0.45037303, 152.18041077]),
#  array([242.85041454, 207.45739686,  13.62875837]),
#  array([ 87.70454545, 231.96519886, 173.6897096 ]),
#  array([  7.82556992, 105.72046529, 245.3133406 ]),
#  array([  2.26228628,   7.46991775, 226.14483053]),
#  array([168.80107772, 241.15316467,  93.86628916]),
#  array([50.32532455, 73.60075567, 98.99302461]),
#  array([ 16.37051758, 202.59621533, 239.24159682])]

# %%
IMAGE_DIRECTORY = 'data/mositure_images/'
COLORS = {
    'GREEN': [0, 128, 0],
    'BLUE': [0, 0, 128],
    'YELLOW': [255, 255, 0]
}
images = []

for file in os.listdir(IMAGE_DIRECTORY):
    if not file.startswith('.'):
        images.append(get_image(os.path.join(IMAGE_DIRECTORY, file)))
        
for i in range(len(images)):
    plt.figure(figsize=(70, 50))
    plt.subplot(1, len(images), i+1)
    plt.imshow(images[i])
    get_colors(images[i], 8, True)
# Out:
# 240000
# Color:  #0a3eee  color abundance:  0.11973333333333333
# Color:  #7ecf92  color abundance:  0.056383333333333334
# Color:  #1285ee  color abundance:  0.09366666666666666
# Color:  #2a366d  color abundance:  0.04652083333333333
# Color:  #0205e5  color abundance:  0.4678041666666667
# Color:  #dcc529  color abundance:  0.0447
# Color:  #23cfe3  color abundance:  0.0721875
# Color:  #020393  color abundance:  0.09900416666666667
# 240000
# Color:  #28c4db  color abundance:  0.09293333333333334
# Color:  #020187  color abundance:  0.31411666666666666
# Color:  #f47b08  color abundance:  0.07585833333333333
# Color:  #87da85  color abundance:  0.07962083333333334
# Color:  #0f68ec  color abundance:  0.10038333333333334
# Color:  #4b5652  color abundance:  0.0357875
# Color:  #030cdb  color abundance:  0.2072875
# Color:  #e2d122  color abundance:  0.0940125
# 240000
# Color:  #000089  color abundance:  0.3376708333333333
# Color:  #056ef7  color abundance:  0.0927875
# Color:  #e0d822  color abundance:  0.0252125
# Color:  #0000bd  color abundance:  0.19230416666666666
# Color:  #293866  color abundance:  0.0430125
# Color:  #6ede9c  color abundance:  0.03236666666666667
# Color:  #0ec7f2  color abundance:  0.0879625
# Color:  #0108e7  color abundance:  0.18868333333333334
# 240000
# Color:  #0104e7  color abundance:  0.5047333333333334
# Color:  #0ecaf3  color abundance:  0.10104583333333333
# Color:  #e3bf20  color abundance:  0.0208625
# Color:  #161d7b  color abundance:  0.07294583333333333
# Color:  #0a85f4  color abundance:  0.11202916666666667
# Color:  #58c8b4  color abundance:  0.042825
# Color:  #9ee171  color abundance:  0.025829166666666667
# Color:  #083ff2  color abundance:  0.11972916666666666
# 240000
# Color:  #6fda9e  color abundance:  0.03855
# Color:  #0205e7  color abundance:  0.30973333333333336
# Color:  #010089  color abundance:  0.3007625
# Color:  #0a83f4  color abundance:  0.096375
# Color:  #d7d72d  color abundance:  0.024883333333333334
# Color:  #18cceb  color abundance:  0.07730416666666666
# Color:  #29386a  color abundance:  0.0430125
# Color:  #073ff4  color abundance:  0.10937916666666667
# 240000
# Color:  #0a3cee  color abundance:  0.11925
# Color:  #7ecf93  color abundance:  0.05719166666666667
# Color:  #0205e5  color abundance:  0.4658625
# Color:  #22cee4  color abundance:  0.07373333333333333
# Color:  #dcc529  color abundance:  0.044929166666666666
# Color:  #2a366e  color abundance:  0.046158333333333336
# Color:  #020393  color abundance:  0.09897916666666666
# Color:  #1183ee  color abundance:  0.09389583333333333
# 240000
# Color:  #030ad7  color abundance:  0.2112875
# Color:  #8ed87e  color abundance:  0.06935416666666666
# Color:  #e7c61d  color abundance:  0.09014166666666666
# Color:  #2cc6d7  color abundance:  0.07808333333333334
# Color:  #010186  color abundance:  0.35705
# Color:  #0f69eb  color abundance:  0.08152916666666667
# Color:  #454f54  color abundance:  0.03750833333333333
# Color:  #f56907  color abundance:  0.07504583333333334
# 240000
# Color:  #0205cf  color abundance:  0.21550416666666666
# Color:  #d9ce2d  color abundance:  0.04515416666666667
# Color:  #00008c  color abundance:  0.46695
# Color:  #0a68f0  color abundance:  0.06066666666666667
# Color:  #f26709  color abundance:  0.037741666666666666
# Color:  #76d395  color abundance:  0.046170833333333335
# Color:  #354359  color abundance:  0.04272083333333333
# Color:  #0fc3f0  color abundance:  0.08509166666666666
# 240000
# Color:  #0ec6f2  color abundance:  0.08852916666666667
# Color:  #0000bd  color abundance:  0.1923
# Color:  #e0d822  color abundance:  0.025233333333333333
# Color:  #000089  color abundance:  0.3376708333333333
# Color:  #6ede9c  color abundance:  0.032391666666666666
# Color:  #293866  color abundance:  0.04301666666666667
# Color:  #0107e7  color abundance:  0.1883125
# Color:  #056df7  color abundance:  0.09254583333333333
# 240000
# Color:  #aaf15b  color abundance:  0.045375
# Color:  #000098  color abundance:  0.3345375
# Color:  #10cbee  color abundance:  0.09677083333333333
# Color:  #0207e2  color abundance:  0.2643375
# Color:  #324962  color abundance:  0.0429875
# Color:  #f3cf0d  color abundance:  0.08247916666666667
# Color:  #59e8ac  color abundance:  0.052983333333333334
# Color:  #076af5  color abundance:  0.08052916666666667
